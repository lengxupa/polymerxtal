# %% [markdown]
# # Histogram Example
#
# This code loads in the output of a run from the Rappture zoo of examples.
#
# https://nanohub.org/infrastructure/rappture/browser/trunk/examples/zoo/histogram

# %%
from hublib import rappture
# Out:
# <script>
# requirejs.config({
#     paths: {
#         'ace': ['//cdnjs.cloudflare.com/ajax/libs/ace/1.2.6/ace'],
#     },
# });
#
# require(['ace'], function(ace) {
#     console.log("ACE loaded :)");
#     return {};
# });
# </script>
#
# <script>
# requirejs.undef('editor');
#
# define('editor', ["jupyter-js-widgets"], function(widgets) {
#
#     var EditorView = widgets.DOMWidgetView.extend({
#
#         // Render the view.
#         render: function() {
#             this.ignorex = false;
#             this.ignorev = false;
#             //console.log('RENDER '+this.model.get('name'));
#             this.div = document.createElement('div');
#             this.div.setAttribute('id', this.model.get('name'));
#             this.el.appendChild(this.div);
#             this.listenTo(this.model, 'change:state', this._state_changed, this);
#             this.listenTo(this.model, 'change:theme', this._theme_changed, this);
# ...

# %%
io = rappture.RapXML('hist_run.xml')

# %%
io
# Out:
# ## INPUTS
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defaultColumnWidth': 150, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': False, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 15, 'minVisibleRows': 8, 'sortable': True, 'filterable': True, 'highlightSelectedCell': False, 'highlightSelectedRow': True}, id='07dbd9f0-6688-49a0-966f-8ff4dbba8bba', precision=5)
# ## OUTPUTS
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defaultColumnWidth': 150, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': False, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 15, 'minVisibleRows': 8, 'sortable': True, 'filterable': True, 'highlightSelectedCell': False, 'highlightSelectedRow': True}, id='a8d5a3bb-9f79-4b42-a0a7-c7414d503a60', precision=5)

# %%
# %matplotlib notebook
io['output.histogram(example)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Here is what Rappture outputs:
#
# <img  src="example_histogram.png" align="left"/>

# %%
io['output.histogram(single)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# For comparison, here is Rappture's output for the same data:
#
#
# <img  src="single_histogram.png" align="left"/>

# %% [markdown]
# Just like Curves, Histograms can have a group id, so they can be plotted together.  Here they are seperated

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1,2)
io['output.histogram(multi1.8)'].plot(single=True, ax=axs[0])
io['output.histogram(multi2)'].plot(single=True, ax=axs[1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Plot them both together like this:

# %%
io['output.histogram(multi2)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# If you prefer them stacked...

# %%
io['output.histogram(multi2)'].plot(stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Here is what Rappture does, which seems VERY wrong. It looks like a stacked barchart, but the heights do not add up. Its behavior for multiple histograms is actually not documented, so maybe it is a *feature*.
# This example is from the zoo examples.
#
# <img  src="multi_histogram.png" align="left"/>

# %% [markdown]
# ## Name-Value Histograms

# %%
io['output.histogram(namevalue)'].plot(horizontal=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Variable-Width Histogram

# %%
io['output.histogram(width)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
