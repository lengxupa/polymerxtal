# %% [markdown]
# # CNTBANDS

# %%
import hublib.rappture as rappture
# Out:
# <script>
# requirejs.config({
#     paths: {
#         'ace': ['//cdnjs.cloudflare.com/ajax/libs/ace/1.2.6/ace'],
#     },
# });
#
# require(['ace'], function(ace) {
#     console.log("ACE loaded :)");
#     return {};
# });
# </script>
#
# <script>
# requirejs.undef('editor');
#
# define('editor', ["jupyter-js-widgets"], function(widgets) {
#
#     var EditorView = widgets.DOMWidgetView.extend({
#
#         // Render the view.
#         render: function() {
#             this.ignorex = false;
#             this.ignorev = false;
#             //console.log('RENDER '+this.model.get('name'));
#             this.div = document.createElement('div');
#             this.div.setAttribute('id', this.model.get('name'));
#             this.el.appendChild(this.div);
#             this.listenTo(this.model, 'change:state', this._state_changed, this);
#             this.listenTo(this.model, 'change:theme', this._theme_changed, this);
# ...

# %%
io = rappture.Tool('cntbands-ext')
io
# Out:
# ## INPUTS
# QgridWidget(grid_options={'defaultColumnWidth': 150, 'highlightSelectedRow': True, 'enableTextSelectionOnCells': True, 'editable': False, 'explicitInitialization': True, 'minVisibleRows': 8, 'enableColumnReorder': False, 'maxVisibleRows': 15, 'sortable': True, 'fullWidthRows': True, 'rowHeight': 28, 'filterable': True, 'autoEdit': False, 'syncColumnCellResize': True, 'forceFitColumns': True, 'highlightSelectedCell': False}, id=u'96e49559-cbbc-4364-8674-2651cc096abe', precision=5)
# ## LOADERS
# QgridWidget(grid_options={'defaultColumnWidth': 150, 'highlightSelectedRow': True, 'enableTextSelectionOnCells': True, 'editable': False, 'explicitInitialization': True, 'minVisibleRows': 8, 'enableColumnReorder': False, 'maxVisibleRows': 15, 'sortable': True, 'fullWidthRows': True, 'rowHeight': 28, 'filterable': True, 'autoEdit': False, 'syncColumnCellResize': True, 'forceFitColumns': True, 'highlightSelectedCell': False}, id=u'0a8e6d18-9a3b-4848-8dd5-0f3b99199cc8', precision=5)

# %%
io['input.loader'] = "/apps/cntbands-ext/current/rappture/examples/GNR.xml"

# %%
io.run()

# %% [markdown]
# ## Get List Outputs

# %%
io.outputs
# Out:
# QgridWidget(grid_options={'defaultColumnWidth': 150, 'highlightSelectedRow': True, 'enableTextSelectionOnCells': True, 'editable': False, 'explicitInitialization': True, 'minVisibleRows': 8, 'enableColumnReorder': False, 'maxVisibleRows': 15, 'sortable': True, 'fullWidthRows': True, 'rowHeight': 28, 'filterable': True, 'autoEdit': False, 'syncColumnCellResize': True, 'forceFitColumns': True, 'highlightSelectedCell': False}, id=u'1ceccc65-e488-4c75-897e-8a555333823a', precision=5)

# %%
# %matplotlib notebook
x = io['output.curve(DOS)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.curve(E2)'].plot(single=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.curve(E2)'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
io['output.structure(ribbon)'].plot()
# Out:
# NGLWidget()

# %%
io['output.structure(cell)'].plot()
# Out:
# NGLWidget()

# %%
print io['output.log'].value
# Out:
# =RAPPTURE-ERROR=>warning: X11 DISPLAY environment variable not set
# =RAPPTURE-ERROR=>
#
#
# ************************
#  Basic Input Parameters
# ************************
#
# Cut-off vector parameters (n,m)
#  7
#  7
#
# Carbon center to center distance (Ang)
#  1.4200
#
# Tight binding overlap integral (eV)
#  3
#
# Carbon nanoribbon type
# B
# N
#
#
# ***************************
# Output of Basic Parameters:
# ***************************
#
# Length of unit cell (nm)
#  0.24595
# Boundary of Brillouin Zone (ktmax)
#  1.2773e+10
# Bandgap Magnitude (eV)
#  0.0051229
# Bandgap Magnitude in units of overlap parameter (t)
#  0.0017076
