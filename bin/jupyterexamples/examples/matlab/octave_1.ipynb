% %% [markdown]
% # Status
%
% Currently, only Octave 4.2 is available for a notebook, although it is possible to have different versions of Octave installed.

% %%
OCTAVE_VERSION
% Out:
% ans = 4.2.0

% %%
pkg list
% Out:
% Package Name    | Version | Installation directory
% ----------------+---------+-----------------------
%        control  |   3.0.0 | .../octave-4.2.0/share/octave/packages/control-3.0.0
% data-smoothing  |   1.3.0 | .../share/octave/packages/data-smoothing-1.3.0
%      dataframe  |   1.1.0 | .../share/octave/packages/dataframe-1.1.0
%         divand  |   1.1.2 | .../octave-4.2.0/share/octave/packages/divand-1.1.2
%        general  |   2.0.0 | .../octave-4.2.0/share/octave/packages/general-2.0.0
%          image  |   2.4.1 | .../octave-4.2.0/share/octave/packages/image-2.4.1
%             io  |   2.4.5 | .../octave-4.2.0/share/octave/packages/io-2.4.5
%          ltfat  |   2.2.0 | .../octave-4.2.0/share/octave/packages/ltfat-2.2.0
%  miscellaneous  |   1.2.1 | .../share/octave/packages/miscellaneous-1.2.1
%         optics  |   0.1.3 | .../octave-4.2.0/share/octave/packages/optics-0.1.3
%          optim  |   1.5.2 | .../octave-4.2.0/share/octave/packages/optim-1.5.2
%         signal  |   1.3.2 | .../octave-4.2.0/share/octave/packages/signal-1.3.2
%     statistics  |   1.3.0 | .../share/octave/packages/statistics-1.3.0
%            stk  |   2.3.4 | .../octave-4.2.0/share/octave/packages/stk-2.3.4
%         struct  |  1.0.14 | .../octave-4.2.0/share/octave/packages/struct-1.0.14
%       symbolic  |   2.4.0 | .../share/octave/packages/symbolic-2.4.0

% %%
%plot -f svg -s 800,400
pkg load signal
t = 2*pi*linspace(0,1,1024);
y = sin(3.14*t) + 0.5*cos(6.09*t) + 0.1*sin(10.11*t+1/6) + 0.1*sin(15.3*t+1/3);

data1 = abs(y)'; # Positive values
[pks idx] = findpeaks(data1);

data2 = y; # Double-sided
[pks2 idx2] = findpeaks(data2,"DoubleSided");
[pks3 idx3] = findpeaks(data2,"DoubleSided","MinPeakHeight",0.5);

subplot(1,2,1)
plot(t,data1,t(idx),data1(idx),'.m')
subplot(1,2,2)
plot(t,data2,t(idx2),data2(idx2),".m;>2*std;",t(idx3),data2(idx3),"or;>0.1;")
legend("Location","NorthOutside","Orientation","horizontal")
