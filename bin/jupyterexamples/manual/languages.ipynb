# %% [markdown]
# ## Language Support
# Python 2, Python 3, Octave, and R are installed. You can select the language when you create a new notebook, or at any time by selecting "Kernel/Change kernel" from the menubar.
# In the future, we will likely add other languages.

# %% [markdown]
# ## Installed Modules
#
# This notebook is running in a linux environment with a large collection of hundreds of scientific packages based on Continuum Analytics Anaconda distribution.  You can get a list of installed packages from within a notebook by executing the cell below.

# %%
# !conda list
# Out:
# # packages in environment at /apps/share64/debian7/anaconda/anaconda3-5.1:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py36he11e457_0
# _r-mutex                  1.0.0                     mro_2
# absl-py                   0.2.0                    py36_0
# alabaster                 0.7.10           py36h306e16b_0
# amqp                      2.2.2                    py36_0    conda-forge
# anaconda-client           1.6.9                    py36_0
# anaconda-navigator        1.7.0                    py36_0
# anaconda-project          0.8.2            py36h44fb852_0
# asdf                      2.0.0                     <pip>
# ase                       3.16.0                     py_0    conda-forge
# asn1crypto                0.24.0                   py36_0
# asteval                   0.9.12                   py36_0    conda-forge
# astor                     0.6.2                    py36_0
# ...
