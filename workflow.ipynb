# %%
from hublib.tool import get_inputs, run_simtool, rdisplay, read, get_outputs_df, get_outputs, get_output_files

# %%
#nb = '/apps/simtools/melting_KIM.ipynb'
nb = 'Chain_Helix.ipynb'
inputs = get_inputs(nb)
inputs
# Out:
# /apps/share64/debian7/anaconda/anaconda-6/lib/python3.7/site-packages/hublib/tool/input_types.py:71: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   input_dict = yaml.load(incell)
# polymer_type:
#     type: Text
#     value: PAN
#     description: Select the polymer type.
#     options: ['PAN', 'PE', 'PP', 'PS', 'POM', 'PTFE', 'PVC']
#
# helice_atoms:
#     type: Number
#     description: Number of chain (backbone) atoms of a motif of the helix
#     value: 2
#     min: 1
#     max: 20
#
# helice_motifs:
#     type: Number
#     description: Number of motifs of the helix
#     value: 3
#     min: 1
#     max: 20
#
# helice_turns:
#     type: Number
#     description: Number of motifs of the helix
#     value: 1
#     min: 1
#     max: 20
#
# monomers:
#     type: Number
#     description: Number of monomers
#     value: 40
#     min: 1
#     max: 5000
#
# tacticity:
#     type: Text
#     value: isotactic
#     description: Select the tacticity of the polymer chain.
#     options: ['isotactic', 'atactic', 'syndiotactic']
#
# chiriality:
#     type: Text
#     value: right
#     description: Select the chiriality of the polymer chain.
#     options: ['left', 'right']
#
# head_tail_defect_ratio:
#     type: Number
#     description: Ratio of head-to-head and tail-to-tail connections
#     value: 0
#     min: 0
#     max: 1
#
# configs:
#     type: Number
#     description: Number of attempts to find a configuration
#     value: 30
#     min: 1
#     max: 5000

# %%
# we can get a list of expected outputs
get_outputs(nb)
# Out:
# /apps/share64/debian7/anaconda/anaconda-6/lib/python3.7/site-packages/hublib/tool/input_types.py:86: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   out_dict = yaml.load(incell)
# Output PDB:
#     type: Text

# %%
# range checking
inputs.monomers.value = 6000
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0a4459da09b4> in <module>
#       1 # range checking
# ----> 2 inputs.monomers.value = 6000
#
# /apps/share64/debian7/anaconda/anaconda-6/lib/python3.7/site-packages/hublib/tool/input_types.py in value(self, newval)
#     263             raise ValueError("Minimum value is %d" % self.min)
#     264         if self.max is not None and newval > self.max:
# --> 265             raise ValueError("Maximum value is %d" % self.max)
#     266         self._value = newval
#     267
#
# ValueError: Maximum value is 5000

# %%
inputs.monomers.value
# Out:
# 40

# %%
inputs.configs.value
# Out:
# 30

# %%
# Element type conversion
inputs.polymer_type.value = 'PP'
inputs
# Out:
# polymer_type:
#     type: Text
#     value: PP
#     description: Select the polymer type.
#     options: ['PAN', 'PE', 'PP', 'PS', 'POM', 'PTFE', 'PVC']
#
# helice_atoms:
#     type: Number
#     description: Number of chain (backbone) atoms of a motif of the helix
#     value: 2
#     min: 1
#     max: 20
#
# helice_motifs:
#     type: Number
#     description: Number of motifs of the helix
#     value: 3
#     min: 1
#     max: 20
#
# helice_turns:
#     type: Number
#     description: Number of motifs of the helix
#     value: 1
#     min: 1
#     max: 20
#
# monomers:
#     type: Number
#     description: Number of monomers
#     value: 40
#     min: 1
#     max: 5000
#
# tacticity:
#     type: Text
#     value: isotactic
#     description: Select the tacticity of the polymer chain.
#     options: ['isotactic', 'atactic', 'syndiotactic']
#
# chiriality:
#     type: Text
#     value: right
#     description: Select the chiriality of the polymer chain.
#     options: ['left', 'right']
#
# head_tail_defect_ratio:
#     type: Number
#     description: Ratio of head-to-head and tail-to-tail connections
#     value: 0
#     min: 0
#     max: 1
#
# configs:
#     type: Number
#     description: Number of attempts to find a configuration
#     value: 30
#     min: 1
#     max: 5000

# %%
# run the SimTool with the input values
run_simtool(nb, 'Run0.ipynb', inputs, outdir='RUNS', append=False)

# if we want, do more runs for comparison, each with different values
#inputs.Tsolid.value = 800
#run_simtool(nb, 'Run1.ipynb', inputs, outdir='RUNS', append=True)
#inputs.Tsolid.value = 1000
#run_simtool(nb, 'Run2.ipynb', inputs, outdir='RUNS', append=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=11.0, style=ProgressStyle(description_wid…

# %%
import imolecule
helix_name = inputs.polymer_type.value + "_helix_%s%s%s%s" % (f'{inputs.helice_atoms.value}_{inputs.helice_motifs.value}_{inputs.helice_turns.value}', 
                                                              '_' + inputs.tacticity.value[:3] if inputs.tacticity.value else '', 
                                                              '+' if inputs.chiriality.value == 'right' else '-' if inputs.chiriality.value == 'left' 
                                                              else '', '_custom' if inputs.head_tail_defect_ratio.value else '')

imolecule.draw(helix_name+'.pdb',size=(1000, 300))#, camera_type="orthographic")
# Out:
# <div id="molecule_17b396f8-1bf1-4657-9e1f-be47a679bac0"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                            paths: {imolecule: ['nbextensions/imolecule.min', 'https://rawgit.com/patrickfuller/imolecule/master/imolecule/js/build/imolecule.min']}});
#            require(['imolecule'], function () {
#                var $d = $('#molecule_17b396f8-1bf1-4657-9e1f-be47a679bac0');
#                $d.width(1000); $d.height(300);
#                $d.imolecule = jQuery.extend({}, imolecule);
#                $d.imolecule.create($d, {drawingType: 'ball and stick',
#                                         cameraType: 'perspective',
#                                         shader: 'lambert',
#                                         showSave: false});
#                $d.imolecule.addElements({});
#                $d.imolecule.draw({"atoms":[{"charge":0.023233344283605805,"element":"H","location":[-0.8250939226522291,-0.06241988950250743,-41.03702209944751]},{"charge":-0.06265650455156077,"element":"C","location":[-0.8250939226522291,-0.06241988950250743,-39.94202209944751]},{"charge":-0.04647923832846377,"element":"C","location":[0.3859060773477836,0.7015801104975026,-39.43602209944751]},{"charge":-0.04810350602010858,"element":"C","location":[0.3869060773478168,0.7015801104975026,-37.90102209944751]},{"charge":0.023233344283605805,"element":"H","location":[-0.8770939226521932,-1.0934198895025133,-39.57702209944751]},{"charge":0.023233344283605805,"element":"H","location":[-1.7390939226522164,0.4185801104974871,-39.578022099447516]},{"charge":0.029556734218129824,"element":"H","location":[1.2999060773477709,0.16958011049746347,-39.725022099447514]},{"charge":-0.06265650455156077,"element":"C","location":[0.3799060773478118,2.14358011049751,-39.91302209944751]},{"charge":0.023233344283605805,"element":"H","location":[-